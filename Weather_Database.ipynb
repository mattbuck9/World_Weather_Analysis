# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 738

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "https://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + weather_api_key
print(url)
# Out:
# https://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=4581c6bf8f35e91216ce5f0ee744c11b

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    #city_url = f"{url}&q={city}&appid={weather_api_key}&units=imperial"
    city_url = f"{url}&q={city}&appid={weather_api_key}&units=imperial"
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H"%M"%S')      
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_humidity,
                         "Cloudiness": city_clouds,
                         "Wind Speed": city_wind,
                         "Country": city_country,
                         "Weather Description": city_description,
                         "Date": city_date})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mar del plata
# Processing Record 2 of Set 1 | kodiak
# Processing Record 3 of Set 1 | rawannawi
# City not found. Skipping...
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | hithadhoo
# Processing Record 6 of Set 1 | ribeira grande
# Processing Record 7 of Set 1 | chiradzulu
# Processing Record 8 of Set 1 | barrow
# Processing Record 9 of Set 1 | tyumentsevo
# Processing Record 10 of Set 1 | berkak
# Processing Record 11 of Set 1 | bethel
# Processing Record 12 of Set 1 | maraa
# Processing Record 13 of Set 1 | avarua
# Processing Record 14 of Set 1 | vaini
# Processing Record 15 of Set 1 | hagere selam
# Processing Record 16 of Set 1 | luderitz
# Processing Record 17 of Set 1 | yellowknife
# Processing Record 18 of Set 1 | williamsport
# Processing Record 19 of Set 1 | longyearbyen
# Processing Record 20 of Set 1 | carnarvon
# Processing Record 21 of Set 1 | broome
# Processing Record 22 of Set 1 | jamestown
# Processing Record 23 of Set 1 | oron
# Processing Record 24 of Set 1 | chokurdakh
# Processing Record 25 of Set 1 | turukhansk
# Processing Record 26 of Set 1 | busselton
# Processing Record 27 of Set 1 | tabiauea
# City not found. Skipping...
# Processing Record 28 of Set 1 | plouzane
# Processing Record 29 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 30 of Set 1 | karauzyak
# City not found. Skipping...
# Processing Record 31 of Set 1 | olafsvik
# Processing Record 32 of Set 1 | college station
# Processing Record 33 of Set 1 | hobart
# Processing Record 34 of Set 1 | tecpan
# Processing Record 35 of Set 1 | matara
# Processing Record 36 of Set 1 | marcon
# Processing Record 37 of Set 1 | hambantota
# Processing Record 38 of Set 1 | mataura
# Processing Record 39 of Set 1 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 40 of Set 1 | sitka
# Processing Record 41 of Set 1 | rikitea
# Processing Record 42 of Set 1 | sindand
# City not found. Skipping...
# Processing Record 43 of Set 1 | caledon
# Processing Record 44 of Set 1 | qaanaaq
# Processing Record 45 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 46 of Set 1 | conde
# Processing Record 47 of Set 1 | vangaindrano
# Processing Record 48 of Set 1 | harper
# Processing Record 49 of Set 1 | manuk mangkaw
# Processing Record 50 of Set 1 | sungairaya
# Processing Record 1 of Set 2 | kapaa
# Processing Record 2 of Set 2 | atuona
# Processing Record 3 of Set 2 | torbay
# Processing Record 4 of Set 2 | hermanus
# Processing Record 5 of Set 2 | nimes
# Processing Record 6 of Set 2 | gobabis
# Processing Record 7 of Set 2 | kahului
# Processing Record 8 of Set 2 | shellbrook
# Processing Record 9 of Set 2 | ugoofaaru
# Processing Record 10 of Set 2 | port alfred
# Processing Record 11 of Set 2 | elizabeth city
# Processing Record 12 of Set 2 | pimenta bueno
# Processing Record 13 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 14 of Set 2 | punta arenas
# Processing Record 15 of Set 2 | nemuro
# Processing Record 16 of Set 2 | rio gallegos
# Processing Record 17 of Set 2 | kaitangata
# Processing Record 18 of Set 2 | chuy
# Processing Record 19 of Set 2 | geraldton
# Processing Record 20 of Set 2 | bredasdorp
# Processing Record 21 of Set 2 | katsuura
# Processing Record 22 of Set 2 | beringovskiy
# Processing Record 23 of Set 2 | cayenne
# Processing Record 24 of Set 2 | pascagoula
# Processing Record 25 of Set 2 | dingle
# Processing Record 26 of Set 2 | vardo
# Processing Record 27 of Set 2 | svetlogorsk
# Processing Record 28 of Set 2 | butaritari
# Processing Record 29 of Set 2 | nouadhibou
# Processing Record 30 of Set 2 | coihaique
# Processing Record 31 of Set 2 | kavieng
# Processing Record 32 of Set 2 | karaul
# City not found. Skipping...
# Processing Record 33 of Set 2 | saint-philippe
# Processing Record 34 of Set 2 | suihua
# Processing Record 35 of Set 2 | hilo
# Processing Record 36 of Set 2 | khatanga
# Processing Record 37 of Set 2 | burica
# City not found. Skipping...
# Processing Record 38 of Set 2 | necochea
# Processing Record 39 of Set 2 | bluff
# Processing Record 40 of Set 2 | hasaki
# Processing Record 41 of Set 2 | acapulco
# Processing Record 42 of Set 2 | el alto
# Processing Record 43 of Set 2 | albany
# Processing Record 44 of Set 2 | golspie
# Processing Record 45 of Set 2 | atasu
# Processing Record 46 of Set 2 | upernavik
# Processing Record 47 of Set 2 | mwinilunga
# Processing Record 48 of Set 2 | anadyr
# Processing Record 49 of Set 2 | ipixuna
# Processing Record 50 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 1 of Set 3 | adrar
# Processing Record 2 of Set 3 | tecoanapa
# Processing Record 3 of Set 3 | touros
# Processing Record 4 of Set 3 | sao filipe
# Processing Record 5 of Set 3 | bakchar
# Processing Record 6 of Set 3 | dunedin
# Processing Record 7 of Set 3 | faanui
# Processing Record 8 of Set 3 | verkhnyaya inta
# Processing Record 9 of Set 3 | agboville
# Processing Record 10 of Set 3 | dikson
# Processing Record 11 of Set 3 | victoria
# Processing Record 12 of Set 3 | georgetown
# Processing Record 13 of Set 3 | barcelona
# Processing Record 14 of Set 3 | mariinskiy posad
# Processing Record 15 of Set 3 | grindavik
# Processing Record 16 of Set 3 | teahupoo
# Processing Record 17 of Set 3 | alice springs
# Processing Record 18 of Set 3 | kalevala
# Processing Record 19 of Set 3 | leshukonskoye
# Processing Record 20 of Set 3 | labuhan
# Processing Record 21 of Set 3 | ahipara
# Processing Record 22 of Set 3 | cape town
# Processing Record 23 of Set 3 | kavaratti
# Processing Record 24 of Set 3 | qeshm
# Processing Record 25 of Set 3 | zachagansk
# City not found. Skipping...
# Processing Record 26 of Set 3 | roma
# Processing Record 27 of Set 3 | severo-kurilsk
# Processing Record 28 of Set 3 | la rioja
# Processing Record 29 of Set 3 | sorong
# Processing Record 30 of Set 3 | praia da vitoria
# Processing Record 31 of Set 3 | zhangjiakou
# Processing Record 32 of Set 3 | aklavik
# Processing Record 33 of Set 3 | souillac
# Processing Record 34 of Set 3 | bafq
# Processing Record 35 of Set 3 | sinnamary
# Processing Record 36 of Set 3 | vostok
# Processing Record 37 of Set 3 | vilhena
# Processing Record 38 of Set 3 | sibu
# Processing Record 39 of Set 3 | ponta do sol
# Processing Record 40 of Set 3 | nioro
# Processing Record 41 of Set 3 | new norfolk
# Processing Record 42 of Set 3 | ilulissat
# Processing Record 43 of Set 3 | coban
# Processing Record 44 of Set 3 | cheyur
# City not found. Skipping...
# Processing Record 45 of Set 3 | sanary-sur-mer
# Processing Record 46 of Set 3 | huarmey
# Processing Record 47 of Set 3 | opuwo
# Processing Record 48 of Set 3 | blomberg
# Processing Record 49 of Set 3 | honolulu
# Processing Record 50 of Set 3 | husavik
# Processing Record 1 of Set 4 | fayaoue
# Processing Record 2 of Set 4 | vila velha
# Processing Record 3 of Set 4 | east london
# Processing Record 4 of Set 4 | rio cuarto
# Processing Record 5 of Set 4 | mutis
# Processing Record 6 of Set 4 | tiksi
# Processing Record 7 of Set 4 | thompson
# Processing Record 8 of Set 4 | tasiilaq
# Processing Record 9 of Set 4 | boa vista
# Processing Record 10 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 11 of Set 4 | riviere-au-renard
# Processing Record 12 of Set 4 | gazni
# City not found. Skipping...
# Processing Record 13 of Set 4 | bathsheba
# Processing Record 14 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 15 of Set 4 | katherine
# Processing Record 16 of Set 4 | stawell
# Processing Record 17 of Set 4 | nizhniy odes
# Processing Record 18 of Set 4 | palkaka
# City not found. Skipping...
# Processing Record 19 of Set 4 | seoul
# Processing Record 20 of Set 4 | krasnogorsk
# Processing Record 21 of Set 4 | marzuq
# Processing Record 22 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 23 of Set 4 | pacific grove
# Processing Record 24 of Set 4 | oranjestad
# Processing Record 25 of Set 4 | san quintin
# Processing Record 26 of Set 4 | yarumal
# Processing Record 27 of Set 4 | orlik
# Processing Record 28 of Set 4 | port blair
# Processing Record 29 of Set 4 | pevek
# Processing Record 30 of Set 4 | konya
# Processing Record 31 of Set 4 | usinsk
# Processing Record 32 of Set 4 | talcahuano
# Processing Record 33 of Set 4 | port elizabeth
# Processing Record 34 of Set 4 | togur
# Processing Record 35 of Set 4 | totma
# Processing Record 36 of Set 4 | akdepe
# Processing Record 37 of Set 4 | makung
# City not found. Skipping...
# Processing Record 38 of Set 4 | arraial do cabo
# Processing Record 39 of Set 4 | noshiro
# Processing Record 40 of Set 4 | poronaysk
# Processing Record 41 of Set 4 | puerto ayora
# Processing Record 42 of Set 4 | iqaluit
# Processing Record 43 of Set 4 | teseney
# Processing Record 44 of Set 4 | katangli
# Processing Record 45 of Set 4 | tigil
# Processing Record 46 of Set 4 | cabo san lucas
# Processing Record 47 of Set 4 | kawambwa
# Processing Record 48 of Set 4 | grand gaube
# Processing Record 49 of Set 4 | sabanalarga
# Processing Record 50 of Set 4 | chadiza
# Processing Record 1 of Set 5 | rafai
# Processing Record 2 of Set 5 | talnakh
# Processing Record 3 of Set 5 | makakilo city
# Processing Record 4 of Set 5 | mayo
# Processing Record 5 of Set 5 | pabbi
# Processing Record 6 of Set 5 | bull savanna
# Processing Record 7 of Set 5 | castro
# Processing Record 8 of Set 5 | namibe
# Processing Record 9 of Set 5 | new richmond
# Processing Record 10 of Set 5 | pasighat
# Processing Record 11 of Set 5 | cadillac
# Processing Record 12 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 13 of Set 5 | piryion
# City not found. Skipping...
# Processing Record 14 of Set 5 | nanortalik
# Processing Record 15 of Set 5 | mpraeso
# Processing Record 16 of Set 5 | manta
# Processing Record 17 of Set 5 | beckley
# Processing Record 18 of Set 5 | padang
# Processing Record 19 of Set 5 | khani
# Processing Record 20 of Set 5 | lagoa
# Processing Record 21 of Set 5 | lorengau
# Processing Record 22 of Set 5 | yaan
# Processing Record 23 of Set 5 | muros
# Processing Record 24 of Set 5 | chililabombwe
# Processing Record 25 of Set 5 | bontang
# Processing Record 26 of Set 5 | paradwip
# City not found. Skipping...
# Processing Record 27 of Set 5 | ryotsu
# Processing Record 28 of Set 5 | akom
# Processing Record 29 of Set 5 | pisco
# Processing Record 30 of Set 5 | barra patuca
# Processing Record 31 of Set 5 | san patricio
# Processing Record 32 of Set 5 | sobolevo
# Processing Record 33 of Set 5 | macau
# Processing Record 34 of Set 5 | boat of garten
# Processing Record 35 of Set 5 | mahebourg
# Processing Record 36 of Set 5 | sangar
# Processing Record 37 of Set 5 | sakakah
# Processing Record 38 of Set 5 | meulaboh
# Processing Record 39 of Set 5 | port augusta
# Processing Record 40 of Set 5 | muzambinho
# Processing Record 41 of Set 5 | alofi
# Processing Record 42 of Set 5 | srednekolymsk
# Processing Record 43 of Set 5 | srivardhan
# Processing Record 44 of Set 5 | provideniya
# Processing Record 45 of Set 5 | balagansk
# Processing Record 46 of Set 5 | klaksvik
# Processing Record 47 of Set 5 | smithers
# Processing Record 48 of Set 5 | cabra
# Processing Record 49 of Set 5 | leningradskiy
# Processing Record 50 of Set 5 | ugep
# Processing Record 1 of Set 6 | macusani
# Processing Record 2 of Set 6 | mount gambier
# Processing Record 3 of Set 6 | hamilton
# Processing Record 4 of Set 6 | paamiut
# Processing Record 5 of Set 6 | tazovskiy
# Processing Record 6 of Set 6 | bengkulu
# Processing Record 7 of Set 6 | buala
# Processing Record 8 of Set 6 | zamora
# Processing Record 9 of Set 6 | lompoc
# Processing Record 10 of Set 6 | nelson bay
# Processing Record 11 of Set 6 | mandalgovi
# Processing Record 12 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 13 of Set 6 | pisek
# Processing Record 14 of Set 6 | razole
# Processing Record 15 of Set 6 | sambava
# Processing Record 16 of Set 6 | bambanglipuro
# Processing Record 17 of Set 6 | vaitape
# Processing Record 18 of Set 6 | khonuu
# City not found. Skipping...
# Processing Record 19 of Set 6 | creel
# Processing Record 20 of Set 6 | yulara
# Processing Record 21 of Set 6 | nikolskoye
# Processing Record 22 of Set 6 | palana
# Processing Record 23 of Set 6 | marsh harbour
# Processing Record 24 of Set 6 | vila franca do campo
# Processing Record 25 of Set 6 | makubetsu
# Processing Record 26 of Set 6 | aquiraz
# Processing Record 27 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 28 of Set 6 | noumea
# Processing Record 29 of Set 6 | melilla
# Processing Record 30 of Set 6 | avera
# Processing Record 31 of Set 6 | saint george
# Processing Record 32 of Set 6 | sidney
# Processing Record 33 of Set 6 | burkhala
# City not found. Skipping...
# Processing Record 34 of Set 6 | arcata
# Processing Record 35 of Set 6 | saskylakh
# Processing Record 36 of Set 6 | vanimo
# Processing Record 37 of Set 6 | dudinka
# Processing Record 38 of Set 6 | duvan
# Processing Record 39 of Set 6 | hanmer springs
# Processing Record 40 of Set 6 | berdigestyakh
# Processing Record 41 of Set 6 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 42 of Set 6 | karratha
# Processing Record 43 of Set 6 | college
# Processing Record 44 of Set 6 | nisia floresta
# Processing Record 45 of Set 6 | lerwick
# Processing Record 46 of Set 6 | arnia
# Processing Record 47 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 48 of Set 6 | tuktoyaktuk
# Processing Record 49 of Set 6 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 50 of Set 6 | naze
# Processing Record 1 of Set 7 | wageningen
# Processing Record 2 of Set 7 | meiganga
# Processing Record 3 of Set 7 | ronda
# Processing Record 4 of Set 7 | tautira
# Processing Record 5 of Set 7 | marawi
# Processing Record 6 of Set 7 | vao
# Processing Record 7 of Set 7 | luan
# Processing Record 8 of Set 7 | nome
# Processing Record 9 of Set 7 | hearst
# Processing Record 10 of Set 7 | kaputa
# Processing Record 11 of Set 7 | ilhabela
# Processing Record 12 of Set 7 | trutnov
# Processing Record 13 of Set 7 | westport
# Processing Record 14 of Set 7 | haines junction
# Processing Record 15 of Set 7 | churapcha
# Processing Record 16 of Set 7 | morondava
# Processing Record 17 of Set 7 | norman wells
# Processing Record 18 of Set 7 | uyuni
# Processing Record 19 of Set 7 | kadykchan
# City not found. Skipping...
# Processing Record 20 of Set 7 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 21 of Set 7 | gat
# Processing Record 22 of Set 7 | mapiripan
# Processing Record 23 of Set 7 | coquimbo
# Processing Record 24 of Set 7 | guerrero negro
# Processing Record 25 of Set 7 | manzil jamil
# City not found. Skipping...
# Processing Record 26 of Set 7 | ushirombo
# Processing Record 27 of Set 7 | benguela
# Processing Record 28 of Set 7 | wulanhaote
# City not found. Skipping...
# Processing Record 29 of Set 7 | fonseca
# Processing Record 30 of Set 7 | selikhino
# Processing Record 31 of Set 7 | lavrentiya
# Processing Record 32 of Set 7 | yeniseysk
# Processing Record 33 of Set 7 | whitehorse
# Processing Record 34 of Set 7 | ancud
# Processing Record 35 of Set 7 | padre bernardo
# Processing Record 36 of Set 7 | kruisfontein
# Processing Record 37 of Set 7 | umm lajj
# Processing Record 38 of Set 7 | arman
# Processing Record 39 of Set 7 | odweyne
# Processing Record 40 of Set 7 | pangnirtung
# Processing Record 41 of Set 7 | norden
# Processing Record 42 of Set 7 | port arthur
# Processing Record 43 of Set 7 | te anau
# Processing Record 44 of Set 7 | sosnovo-ozerskoye
# Processing Record 45 of Set 7 | esperance
# Processing Record 46 of Set 7 | dauriya
# Processing Record 47 of Set 7 | isangel
# Processing Record 48 of Set 7 | shirokiy
# Processing Record 49 of Set 7 | kirakira
# Processing Record 50 of Set 7 | tumaco
# Processing Record 1 of Set 8 | beloha
# Processing Record 2 of Set 8 | sarakhs
# Processing Record 3 of Set 8 | scarborough
# Processing Record 4 of Set 8 | phonhong
# Processing Record 5 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 6 of Set 8 | moindou
# Processing Record 7 of Set 8 | kirovohrad
# Processing Record 8 of Set 8 | barabai
# Processing Record 9 of Set 8 | lucapa
# Processing Record 10 of Set 8 | fairbanks
# Processing Record 11 of Set 8 | asandh
# Processing Record 12 of Set 8 | khowst
# Processing Record 13 of Set 8 | cherskiy
# Processing Record 14 of Set 8 | ostrovnoy
# Processing Record 15 of Set 8 | tura
# Processing Record 16 of Set 8 | narsaq
# Processing Record 17 of Set 8 | charlestown
# Processing Record 18 of Set 8 | roald
# Processing Record 19 of Set 8 | waipawa
# Processing Record 20 of Set 8 | goderich
# Processing Record 21 of Set 8 | havoysund
# Processing Record 22 of Set 8 | yichang
# Processing Record 23 of Set 8 | rodos
# Processing Record 24 of Set 8 | cah ab
# City not found. Skipping...
# Processing Record 25 of Set 8 | akureyri
# Processing Record 26 of Set 8 | hualmay
# Processing Record 27 of Set 8 | malinovoye ozero
# Processing Record 28 of Set 8 | kudahuvadhoo
# Processing Record 29 of Set 8 | bubaque
# Processing Record 30 of Set 8 | havelock
# Processing Record 31 of Set 8 | ishigaki
# Processing Record 32 of Set 8 | qadian
# Processing Record 33 of Set 8 | mehamn
# Processing Record 34 of Set 8 | north bend
# Processing Record 35 of Set 8 | utete
# Processing Record 36 of Set 8 | bronnoysund
# Processing Record 37 of Set 8 | burla
# Processing Record 38 of Set 8 | oriximina
# Processing Record 39 of Set 8 | verkhnevilyuysk
# Processing Record 40 of Set 8 | salinopolis
# Processing Record 41 of Set 8 | trincomalee
# Processing Record 42 of Set 8 | constitucion
# Processing Record 43 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 44 of Set 8 | linqiong
# Processing Record 45 of Set 8 | port lincoln
# Processing Record 46 of Set 8 | hohhot
# Processing Record 47 of Set 8 | lardos
# Processing Record 48 of Set 8 | vanavara
# Processing Record 49 of Set 8 | minsk
# Processing Record 50 of Set 8 | santa fe
# Processing Record 1 of Set 9 | halkirk
# Processing Record 2 of Set 9 | prainha
# Processing Record 3 of Set 9 | priargunsk
# Processing Record 4 of Set 9 | madison
# Processing Record 5 of Set 9 | lebu
# Processing Record 6 of Set 9 | madimba
# Processing Record 7 of Set 9 | nkowakowa
# Processing Record 8 of Set 9 | cidreira
# Processing Record 9 of Set 9 | laguna
# Processing Record 10 of Set 9 | oshkosh
# Processing Record 11 of Set 9 | hofn
# Processing Record 12 of Set 9 | abha
# Processing Record 13 of Set 9 | lasa
# Processing Record 14 of Set 9 | hauge
# Processing Record 15 of Set 9 | nuevo casas grandes
# Processing Record 16 of Set 9 | yelizovo
# Processing Record 17 of Set 9 | caravelas
# Processing Record 18 of Set 9 | bonoua
# Processing Record 19 of Set 9 | cockburn town
# Processing Record 20 of Set 9 | kieta
# Processing Record 21 of Set 9 | mugur-aksy
# Processing Record 22 of Set 9 | la asuncion
# Processing Record 23 of Set 9 | alibag
# Processing Record 24 of Set 9 | verkhoturye
# Processing Record 25 of Set 9 | lake havasu city
# Processing Record 26 of Set 9 | saint anthony
# Processing Record 27 of Set 9 | airai
# Processing Record 28 of Set 9 | nichinan
# Processing Record 29 of Set 9 | olden
# Processing Record 30 of Set 9 | lishu
# Processing Record 31 of Set 9 | rundu
# Processing Record 32 of Set 9 | quatre cocos
# Processing Record 33 of Set 9 | kang
# Processing Record 34 of Set 9 | novyy urengoy
# Processing Record 35 of Set 9 | chabahar
# Processing Record 36 of Set 9 | kalachinsk
# Processing Record 37 of Set 9 | andenes
# Processing Record 38 of Set 9 | naqadeh
# Processing Record 39 of Set 9 | koygorodok
# Processing Record 40 of Set 9 | lodja
# Processing Record 41 of Set 9 | prince rupert
# Processing Record 42 of Set 9 | marondera
# Processing Record 43 of Set 9 | vytegra
# Processing Record 44 of Set 9 | brigham city
# Processing Record 45 of Set 9 | aksarka
# Processing Record 46 of Set 9 | cap malheureux
# Processing Record 47 of Set 9 | qianan
# Processing Record 48 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 49 of Set 9 | baiquan
# Processing Record 50 of Set 9 | riyadh
# Processing Record 1 of Set 10 | hovd
# Processing Record 2 of Set 10 | moen
# Processing Record 3 of Set 10 | kitgum
# Processing Record 4 of Set 10 | port moresby
# Processing Record 5 of Set 10 | mecca
# Processing Record 6 of Set 10 | arandis
# Processing Record 7 of Set 10 | pueblo nuevo
# Processing Record 8 of Set 10 | sorland
# Processing Record 9 of Set 10 | tyukhtet
# Processing Record 10 of Set 10 | vila
# Processing Record 11 of Set 10 | marrakesh
# Processing Record 12 of Set 10 | iquique
# Processing Record 13 of Set 10 | den helder
# Processing Record 14 of Set 10 | saldanha
# Processing Record 15 of Set 10 | fortuna
# Processing Record 16 of Set 10 | ruteng
# Processing Record 17 of Set 10 | villaviciosa
# Processing Record 18 of Set 10 | tanabe
# Processing Record 19 of Set 10 | lagos
# Processing Record 20 of Set 10 | ulaangom
# Processing Record 21 of Set 10 | honiara
# Processing Record 22 of Set 10 | alexandria
# Processing Record 23 of Set 10 | langham
# Processing Record 24 of Set 10 | xuddur
# Processing Record 25 of Set 10 | chake chake
# Processing Record 26 of Set 10 | sar-e pul
# Processing Record 27 of Set 10 | tomatlan
# Processing Record 28 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 29 of Set 10 | norfolk
# Processing Record 30 of Set 10 | bardiyah
# Processing Record 31 of Set 10 | raga
# Processing Record 32 of Set 10 | comodoro rivadavia
# Processing Record 33 of Set 10 | bambous virieux
# Processing Record 34 of Set 10 | port macquarie
# Processing Record 35 of Set 10 | bonavista
# Processing Record 36 of Set 10 | gazanjyk
# Processing Record 37 of Set 10 | udachnyy
# Processing Record 38 of Set 10 | miraflores
# Processing Record 39 of Set 10 | fort saint john
# City not found. Skipping...
# Processing Record 40 of Set 10 | port-gentil
# Processing Record 41 of Set 10 | quzhou
# Processing Record 42 of Set 10 | kaka
# Processing Record 43 of Set 10 | sedelnikovo
# City not found. Skipping...
# Processing Record 44 of Set 10 | hakkari
# Processing Record 45 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 46 of Set 10 | camana
# Processing Record 47 of Set 10 | pemangkat
# Processing Record 48 of Set 10 | teya
# Processing Record 49 of Set 10 | san andres
# Processing Record 50 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 1 of Set 11 | puerto colombia
# Processing Record 2 of Set 11 | muisne
# Processing Record 3 of Set 11 | mazyr
# Processing Record 4 of Set 11 | yilan
# Processing Record 5 of Set 11 | nola
# Processing Record 6 of Set 11 | lehrte
# Processing Record 7 of Set 11 | syracuse
# Processing Record 8 of Set 11 | gigmoto
# Processing Record 9 of Set 11 | carbonia
# Processing Record 10 of Set 11 | soyo
# Processing Record 11 of Set 11 | quang ngai
# Processing Record 12 of Set 11 | qasigiannguit
# Processing Record 13 of Set 11 | abu zabad
# Processing Record 14 of Set 11 | mount isa
# Processing Record 15 of Set 11 | kropotkin
# Processing Record 16 of Set 11 | mataquescuintla
# Processing Record 17 of Set 11 | ilo
# Processing Record 18 of Set 11 | inhambane
# Processing Record 19 of Set 11 | lemesos
# City not found. Skipping...
# Processing Record 20 of Set 11 | kingsport
# Processing Record 21 of Set 11 | yuli
# Processing Record 22 of Set 11 | okato
# Processing Record 23 of Set 11 | pochutla
# Processing Record 24 of Set 11 | bijie
# Processing Record 25 of Set 11 | maputo
# Processing Record 26 of Set 11 | tsihombe
# City not found. Skipping...
# Processing Record 27 of Set 11 | fukue
# Processing Record 28 of Set 11 | pathein
# Processing Record 29 of Set 11 | toccoa
# Processing Record 30 of Set 11 | biltine
# Processing Record 31 of Set 11 | huainan
# Processing Record 32 of Set 11 | malindi
# Processing Record 33 of Set 11 | sroda wielkopolska
# Processing Record 34 of Set 11 | diu
# Processing Record 35 of Set 11 | atambua
# Processing Record 36 of Set 11 | porto novo
# Processing Record 37 of Set 11 | iskateley
# Processing Record 38 of Set 11 | coihueco
# Processing Record 39 of Set 11 | vestmanna
# Processing Record 40 of Set 11 | nangomba
# Processing Record 41 of Set 11 | marsa matruh
# Processing Record 42 of Set 11 | amderma
# City not found. Skipping...
# Processing Record 43 of Set 11 | ahuimanu
# Processing Record 44 of Set 11 | ludvika
# Processing Record 45 of Set 11 | praia
# Processing Record 46 of Set 11 | poyarkovo
# Processing Record 47 of Set 11 | korla
# Processing Record 48 of Set 11 | bandarbeyla
# Processing Record 49 of Set 11 | ciudad bolivar
# Processing Record 50 of Set 11 | valera
# Processing Record 1 of Set 12 | karasuk
# Processing Record 2 of Set 12 | yeppoon
# Processing Record 3 of Set 12 | thakurgaon
# Processing Record 4 of Set 12 | chernyakhovsk
# Processing Record 5 of Set 12 | tver
# Processing Record 6 of Set 12 | hay river
# Processing Record 7 of Set 12 | awbari
# Processing Record 8 of Set 12 | pombas
# Processing Record 9 of Set 12 | reconquista
# Processing Record 10 of Set 12 | maragogi
# Processing Record 11 of Set 12 | gizo
# Processing Record 12 of Set 12 | arco
# Processing Record 13 of Set 12 | ashland
# Processing Record 14 of Set 12 | lazaro cardenas
# Processing Record 15 of Set 12 | codrington
# Processing Record 16 of Set 12 | melbu
# Processing Record 17 of Set 12 | pozo colorado
# Processing Record 18 of Set 12 | bereda
# Processing Record 19 of Set 12 | kresttsy
# Processing Record 20 of Set 12 | athabasca
# Processing Record 21 of Set 12 | barbar
# City not found. Skipping...
# Processing Record 22 of Set 12 | edwardsville
# Processing Record 23 of Set 12 | loding
# Processing Record 24 of Set 12 | komsomolskiy
# Processing Record 25 of Set 12 | yar-sale
# Processing Record 26 of Set 12 | bida
# Processing Record 27 of Set 12 | kualakapuas
# Processing Record 28 of Set 12 | idio
# Processing Record 29 of Set 12 | turbat
# Processing Record 30 of Set 12 | yudong
# Processing Record 31 of Set 12 | bokajan
# Processing Record 32 of Set 12 | ermelo
# Processing Record 33 of Set 12 | santiago del estero
# Processing Record 34 of Set 12 | bima
# Processing Record 35 of Set 12 | ferme-neuve
# Processing Record 36 of Set 12 | barranca
# Processing Record 37 of Set 12 | biak
# Processing Record 38 of Set 12 | perepravnaya
# Processing Record 39 of Set 12 | zigong
# Processing Record 40 of Set 12 | mayumba
# Processing Record 41 of Set 12 | sao joao da barra
# Processing Record 42 of Set 12 | lubango
# Processing Record 43 of Set 12 | markova
# Processing Record 44 of Set 12 | galdar
# Processing Record 45 of Set 12 | ust-maya
# Processing Record 46 of Set 12 | bud
# Processing Record 47 of Set 12 | sioux lookout
# Processing Record 48 of Set 12 | magdagachi
# Processing Record 49 of Set 12 | badajoz
# Processing Record 50 of Set 12 | vestmannaeyjar
# Processing Record 1 of Set 13 | araouane
# Processing Record 2 of Set 13 | toungoo
# City not found. Skipping...
# Processing Record 3 of Set 13 | umm durman
# City not found. Skipping...
# Processing Record 4 of Set 13 | kargasok
# Processing Record 5 of Set 13 | joshimath
# Processing Record 6 of Set 13 | guarapari
# Processing Record 7 of Set 13 | blankenberge
# Processing Record 8 of Set 13 | el carmen
# Processing Record 9 of Set 13 | asfi
# Processing Record 10 of Set 13 | san cristobal
# Processing Record 11 of Set 13 | jumla
# Processing Record 12 of Set 13 | nuristan
# Processing Record 13 of Set 13 | monastyrshchina
# Processing Record 14 of Set 13 | washougal
# Processing Record 15 of Set 13 | auki
# Processing Record 16 of Set 13 | ojinaga
# Processing Record 17 of Set 13 | tokur
# Processing Record 18 of Set 13 | mandera
# Processing Record 19 of Set 13 | skelmorlie
# Processing Record 20 of Set 13 | bolivar
# Processing Record 21 of Set 13 | port angeles
# Processing Record 22 of Set 13 | san juan
# Processing Record 23 of Set 13 | gumdag
# Processing Record 24 of Set 13 | kon tum
# Processing Record 25 of Set 13 | klyuchi
# Processing Record 26 of Set 13 | bargal
# City not found. Skipping...
# Processing Record 27 of Set 13 | sahuaripa
# Processing Record 28 of Set 13 | bodri
# Processing Record 29 of Set 13 | sistranda
# Processing Record 30 of Set 13 | guanare
# Processing Record 31 of Set 13 | dolbeau
# City not found. Skipping...
# Processing Record 32 of Set 13 | antofagasta
# Processing Record 33 of Set 13 | yomou
# Processing Record 34 of Set 13 | pendleton
# Processing Record 35 of Set 13 | zhoucheng
# Processing Record 36 of Set 13 | coahuayana
# Processing Record 37 of Set 13 | nhulunbuy
# Processing Record 38 of Set 13 | ambilobe
# Processing Record 39 of Set 13 | buchanan
# Processing Record 40 of Set 13 | lahad datu
# Processing Record 41 of Set 13 | galiwinku
# City not found. Skipping...
# Processing Record 42 of Set 13 | buraydah
# Processing Record 43 of Set 13 | satitoa
# City not found. Skipping...
# Processing Record 44 of Set 13 | benin
# Processing Record 45 of Set 13 | qaqortoq
# Processing Record 46 of Set 13 | rivne
# Processing Record 47 of Set 13 | kodinsk
# Processing Record 48 of Set 13 | longlac
# City not found. Skipping...
# Processing Record 49 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 50 of Set 13 | dinsor
# City not found. Skipping...
# Processing Record 1 of Set 14 | kotma
# Processing Record 2 of Set 14 | tselinnoye
# Processing Record 3 of Set 14 | bovenden
# Processing Record 4 of Set 14 | san rafael
# Processing Record 5 of Set 14 | rocha
# Processing Record 6 of Set 14 | kwinana
# Processing Record 7 of Set 14 | cockburn harbour
# City not found. Skipping...
# Processing Record 8 of Set 14 | surt
# Processing Record 9 of Set 14 | tanem
# Processing Record 10 of Set 14 | hervey bay
# Processing Record 11 of Set 14 | phan thiet
# Processing Record 12 of Set 14 | sola
# Processing Record 13 of Set 14 | nizhnyaya omka
# Processing Record 14 of Set 14 | balkanabat
# Processing Record 15 of Set 14 | henties bay
# Processing Record 16 of Set 14 | ekibastuz
# Processing Record 17 of Set 14 | bacuit
# City not found. Skipping...
# Processing Record 18 of Set 14 | bodden town
# Processing Record 19 of Set 14 | joanopolis
# Processing Record 20 of Set 14 | lamu
# Processing Record 21 of Set 14 | bintulu
# Processing Record 22 of Set 14 | raudeberg
# Processing Record 23 of Set 14 | turayf
# Processing Record 24 of Set 14 | yanan
# City not found. Skipping...
# Processing Record 25 of Set 14 | sisimiut
# Processing Record 26 of Set 14 | tucurui
# Processing Record 27 of Set 14 | malartic
# Processing Record 28 of Set 14 | saint augustine
# Processing Record 29 of Set 14 | mahroni
# Processing Record 30 of Set 14 | fecamp
# Processing Record 31 of Set 14 | carsamba
# Processing Record 32 of Set 14 | flinders
# Processing Record 33 of Set 14 | saint-joseph
# Processing Record 34 of Set 14 | girvan
# Processing Record 35 of Set 14 | ketchikan
# Processing Record 36 of Set 14 | mastic
# Processing Record 37 of Set 14 | kizema
# Processing Record 38 of Set 14 | muriwai beach
# Processing Record 39 of Set 14 | berlevag
# Processing Record 40 of Set 14 | hobyo
# Processing Record 41 of Set 14 | rehoboth
# Processing Record 42 of Set 14 | clyde river
# Processing Record 43 of Set 14 | herisau
# Processing Record 44 of Set 14 | tooele
# Processing Record 45 of Set 14 | saint-pierre
# Processing Record 46 of Set 14 | wampusirpi
# City not found. Skipping...
# Processing Record 47 of Set 14 | damietta
# Processing Record 48 of Set 14 | albert town
# Processing Record 49 of Set 14 | wanaka
# Processing Record 50 of Set 14 | jiddah
# City not found. Skipping...
# Processing Record 1 of Set 15 | malwan
# City not found. Skipping...
# Processing Record 2 of Set 15 | trapani
# Processing Record 3 of Set 15 | havre-saint-pierre
# Processing Record 4 of Set 15 | barhi
# Processing Record 5 of Set 15 | slave lake
# Processing Record 6 of Set 15 | tarakan
# Processing Record 7 of Set 15 | cumaribo
# City not found. Skipping...
# Processing Record 8 of Set 15 | dalby
# Processing Record 9 of Set 15 | mogocha
# Processing Record 10 of Set 15 | mizdah
# Processing Record 11 of Set 15 | sikasso
# Processing Record 12 of Set 15 | eureka
# Processing Record 13 of Set 15 | copiapo
# Processing Record 14 of Set 15 | balod
# Processing Record 15 of Set 15 | puerto del rosario
# Processing Record 16 of Set 15 | tadine
# Processing Record 17 of Set 15 | vrangel
# Processing Record 18 of Set 15 | pedasi
# Processing Record 19 of Set 15 | dzhebariki-khaya
# Processing Record 20 of Set 15 | atar
# Processing Record 21 of Set 15 | wanning
# Processing Record 22 of Set 15 | deputatskiy
# Processing Record 23 of Set 15 | konakovo
# Processing Record 24 of Set 15 | jalu
# Processing Record 25 of Set 15 | talakan
# Processing Record 26 of Set 15 | camacha
# Processing Record 27 of Set 15 | hof
# Processing Record 28 of Set 15 | fort nelson
# Processing Record 29 of Set 15 | mount darwin
# Processing Record 30 of Set 15 | curanilahue
# Processing Record 31 of Set 15 | port hardy
# Processing Record 32 of Set 15 | wagar
# Processing Record 33 of Set 15 | puruaran
# Processing Record 34 of Set 15 | shingu
# Processing Record 35 of Set 15 | methoni
# Processing Record 36 of Set 15 | muroto
# Processing Record 37 of Set 15 | springfield
# Processing Record 38 of Set 15 | sunland park
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 676

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Mar Del Plata -38.0023  -57.5575     54.09        81           0
# 1          Kodiak  57.7900 -152.4072     51.31        76         100
# 2         Ushuaia -54.8000  -68.3000     47.86        61           0
# 3       Hithadhoo  -0.6000   73.0833     81.73        71          98
# 4  Ribeira Grande  38.5167  -28.7000     70.11        81          99
# 5      Chiradzulu -15.6746   35.1407     69.51        42           1
# 6          Barrow  71.2906 -156.7887     24.82        93         100
# 7     Tyumentsevo  53.3224   81.4980     30.06        90           1
# 8          Berkak  62.8250   10.0118     42.94        84          92
# 9          Bethel  41.3712  -73.4140     52.57        73         100
#
#    Wind Speed Country Weather Description                 Date
# 0        9.22      AR           clear sky  2022-10-03 22"50"43
# 1       10.36      US          light rain  2022-10-03 22"50"44
# 2        3.44      AR           clear sky  2022-10-03 22"50"45
# 3       15.30      MV     overcast clouds  2022-10-03 22"50"45
# 4        3.76      PT     overcast clouds  2022-10-03 22"50"46
# 5        3.38      MW           clear sky  2022-10-03 22"50"46
# 6       19.57      US     overcast clouds  2022-10-03 22"48"08
# 7        6.73      RU           clear sky  2022-10-03 22"50"47
# 8        6.76      NO     overcast clouds  2022-10-03 22"50"48
# 9        5.99      US       moderate rain  2022-10-03 22"50"49

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Current Description', 'Humidity',
#        'Cloudiness', 'Wind Speed', 'Country'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City","Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Weather Description"]

# Recreate the DataFrame by using the new column order
city_data_ordered_df = city_data_df[new_column_order]

# Display sample data
city_data_ordered_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Mar Del Plata      AR -38.0023  -57.5575     54.09        81           0
# 1          Kodiak      US  57.7900 -152.4072     51.31        76         100
# 2         Ushuaia      AR -54.8000  -68.3000     47.86        61           0
# 3       Hithadhoo      MV  -0.6000   73.0833     81.73        71          98
# 4  Ribeira Grande      PT  38.5167  -28.7000     70.11        81          99
# 5      Chiradzulu      MW -15.6746   35.1407     69.51        42           1
# 6          Barrow      US  71.2906 -156.7887     24.82        93         100
# 7     Tyumentsevo      RU  53.3224   81.4980     30.06        90           1
# 8          Berkak      NO  62.8250   10.0118     42.94        84          92
# 9          Bethel      US  41.3712  -73.4140     52.57        73         100
#
#    Wind Speed Weather Description
# 0        9.22           clear sky
# 1       10.36          light rain
# 2        3.44           clear sky
# 3       15.30     overcast clouds
# 4        3.76     overcast clouds
# 5        3.38           clear sky
# 6       19.57     overcast clouds
# 7        6.73           clear sky
# 8        6.76     overcast clouds
# 9        5.99       moderate rain

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_ordered_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Weather Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_ordered_df.to_csv(output_data_file, index_label="City_ID")
